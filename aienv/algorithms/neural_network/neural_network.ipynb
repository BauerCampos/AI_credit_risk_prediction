# %%
import pickle
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
from yellowbrick.classifier import ConfusionMatrix

# %%
with open('../../database/processed_data/credit.pkl', 'rb') as f:
    x_credit_training, y_credit_training, x_credit_test, y_credit_test = pickle.load(f)

# %%
model = MLPClassifier(max_iter=1500, verbose=True, tol=0.000100, solver='adam', activation='relu', hidden_layer_sizes=(16,16))
model.fit(x_credit_training, y_credit_training)
# Out:
# Iteration 1, loss = 0.49879161
# Iteration 2, loss = 0.35985157
# Iteration 3, loss = 0.33040640
# Iteration 4, loss = 0.31587287
# Iteration 5, loss = 0.30630098
# Iteration 6, loss = 0.29928832
# Iteration 7, loss = 0.29369971
# Iteration 8, loss = 0.28931739
# Iteration 9, loss = 0.28538358
# Iteration 10, loss = 0.28204750
# Iteration 11, loss = 0.27853361
# Iteration 12, loss = 0.27541464
# Iteration 13, loss = 0.27195433
# Iteration 14, loss = 0.26896651
# Iteration 15, loss = 0.26620538
# Iteration 16, loss = 0.26369072
# Iteration 17, loss = 0.26144536
# Iteration 18, loss = 0.25950132
# Iteration 19, loss = 0.25705240
# Iteration 20, loss = 0.25605472
# Iteration 21, loss = 0.25406204
# Iteration 22, loss = 0.25261977
# Iteration 23, loss = 0.25118611
# Iteration 24, loss = 0.24986327
# Iteration 25, loss = 0.24877921
# Iteration 26, loss = 0.24731146
# Iteration 27, loss = 0.24624083
# Iteration 28, loss = 0.24508972
# Iteration 29, loss = 0.24414237
# ...

# %%
prediction = model.predict(x_credit_test)

# %%
accuracy_score(y_credit_test, prediction)
# Out:
# 0.9270628683693517

# %%
cm = ConfusionMatrix(model)
cm.fit(x_credit_training, y_credit_training)
cm.score(x_credit_test, y_credit_test)
# Out:
# 0.9270628683693517

# %%
print(classification_report(y_credit_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      6435
#            1       0.94      0.70      0.80      1709
#
#     accuracy                           0.93      8144
#    macro avg       0.93      0.84      0.88      8144
# weighted avg       0.93      0.93      0.92      8144
